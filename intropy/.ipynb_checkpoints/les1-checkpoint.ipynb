# %%
import pandas
pandas.__version__
# Out:
# '2.2.2'

# %%
import pandas as pd

# %%
cal_df = pd.read_csv('Calories.csv')
sub_df = pd.read_csv('subset-covid-data.csv')

# %%
cal_df.head(170)
# Out:
#      Duration       Date  Pulse  Maxpulse  Calories
# 0          60  12/1/2020    110       130     409.1
# 1          60  12/2/2020    117       145     479.0
# 2          60  12/3/2020    103       135     340.0
# 3          45  12/5/2020    109       175     282.4
# 4          45  12/5/2020    109       175     282.4
# ..        ...        ...    ...       ...       ...
# 164        60        NaN    105       140     290.8
# 165        60        NaN    110       145     300.0
# 166        60        NaN    115       145     310.2
# 167        75        NaN    120       150     320.4
# 168        75        NaN    125       150     330.4
#
# [169 rows x 5 columns]

# %%
import pandas as pd

print(cal_df.to_string())
# Out:
#      Duration        Date  Pulse  Maxpulse  Calories
# 0          60   12/1/2020    110       130     409.1
# 1          60   12/2/2020    117       145     479.0
# 2          60   12/3/2020    103       135     340.0
# 3          45   12/5/2020    109       175     282.4
# 4          45   12/5/2020    109       175     282.4
# 5          60   12/6/2020    102       127     300.0
# 6          60   12/7/2020    110       136     374.0
# 7          45   12/8/2020    104       134     253.3
# 8          30   12/9/2020    109       133     195.1
# 9          60  12/10/2020     98       124     269.0
# 10         60  12/11/2020    103       147     329.3
# 11         60  12/12/2020    100       120     250.7
# 12         60  12/12/2020    100       120     250.7
# 13         60  12/13/2020    104       132     379.3
# 14         60  12/14/2020     98       123     275.0
# 15         60  12/15/2020     98       120     215.2
# 16         60  12/16/2020    100       120     300.0
# ...

# %%
sub_df.head(207)
# Out:
#          country continent        date  day  month  year  cases  deaths  \
# 0    Afghanistan      Asia  2020-04-12   12      4  2020     34       3
# 1        Albania    Europe  2020-04-12   12      4  2020     17       0
# 2        Algeria    Africa  2020-04-12   12      4  2020     64      19
# 3        Andorra    Europe  2020-04-12   12      4  2020     21       2
# 4         Angola    Africa  2020-04-12   12      4  2020      0       0
# ..           ...       ...         ...  ...    ...   ...    ...     ...
# 201    Venezuela   America  2020-04-12   12      4  2020      0       0
# 202      Vietnam      Asia  2020-04-12   12      4  2020      4       0
# 203        Yemen      Asia  2020-04-12   12      4  2020      0       0
# 204       Zambia    Africa  2020-04-12   12      4  2020      0       0
# 205     Zimbabwe    Africa  2020-04-12   12      4  2020      3       0
#
#     country_code  population
# 0            AFG  37172386.0
# 1            ALB   2866376.0
# ...

# %%
import pandas as pd

print(pd.options.display.max_rows)
pd.options.display.max_rows = 9999

print(pd.options.display.max_rows)
# Out:
# 100
# 9999

# %%
print(sub_df.tail())
# Out:
#        country continent        date  day  month  year  cases  deaths  \
# 201  Venezuela   America  2020-04-12   12      4  2020      0       0
# 202    Vietnam      Asia  2020-04-12   12      4  2020      4       0
# 203      Yemen      Asia  2020-04-12   12      4  2020      0       0
# 204     Zambia    Africa  2020-04-12   12      4  2020      0       0
# 205   Zimbabwe    Africa  2020-04-12   12      4  2020      3       0
#
#     country_code  population
# 201          VEN  28870195.0
# 202          VNM  95540395.0
# 203          YEM  28498687.0
# 204          ZMB  17351822.0
# 205          ZWE  14439018.0

# %% [markdown]
# Cleaning data

# %%
import pandas as pd

print("The first 10 rows: ")
print(sub_df.head(10))

print("\nThe last 10 rows: ")
print(sub_df.tail(10))

print(sub_df.info())
# Out:
# The first 10 rows:
#                country continent        date  day  month  year  cases  deaths  \
# 0          Afghanistan      Asia  2020-04-12   12      4  2020     34       3
# 1              Albania    Europe  2020-04-12   12      4  2020     17       0
# 2              Algeria    Africa  2020-04-12   12      4  2020     64      19
# 3              Andorra    Europe  2020-04-12   12      4  2020     21       2
# 4               Angola    Africa  2020-04-12   12      4  2020      0       0
# 5             Anguilla   America  2020-04-12   12      4  2020      0       0
# 6  Antigua_and_Barbuda   America  2020-04-12   12      4  2020      0       0
# 7            Argentina   America  2020-04-12   12      4  2020    162       7
# 8              Armenia    Europe  2020-04-12   12      4  2020     30       2
# 9                Aruba   America  2020-04-12   12      4  2020      6       0
#
#   country_code  population
# 0          AFG  37172386.0
# 1          ALB   2866376.0
# ...

# %%
print(sub_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country       206 non-null    object
#  1   continent     206 non-null    object
#  2   date          206 non-null    object
#  3   day           206 non-null    int64
#  4   month         206 non-null    int64
#  5   year          206 non-null    int64
#  6   cases         206 non-null    int64
#  7   deaths        206 non-null    int64
#  8   country_code  202 non-null    object
#  9   population    202 non-null    float64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 16.2+ KB
# None

# %%
sub_df.head(5)
# Out:
#        country continent        date  day  month  year  cases  deaths  \
# 0  Afghanistan      Asia  2020-04-12   12      4  2020     34       3
# 1      Albania    Europe  2020-04-12   12      4  2020     17       0
# 2      Algeria    Africa  2020-04-12   12      4  2020     64      19
# 3      Andorra    Europe  2020-04-12   12      4  2020     21       2
# 4       Angola    Africa  2020-04-12   12      4  2020      0       0
#
#   country_code  population
# 0          AFG  37172386.0
# 1          ALB   2866376.0
# 2          DZA  42228429.0
# 3          AND     77006.0
# 4          AGO  30809762.0

# %%
import pandas as pd
new_sub_df = sub_df.dropna()
print(new_sub_df)
print(new_sub_df.info())
# Out:
#          country continent        date  day  month  year  cases  deaths  \
# 0    Afghanistan      Asia  2020-04-12   12      4  2020     34       3
# 1        Albania    Europe  2020-04-12   12      4  2020     17       0
# 2        Algeria    Africa  2020-04-12   12      4  2020     64      19
# 3        Andorra    Europe  2020-04-12   12      4  2020     21       2
# 4         Angola    Africa  2020-04-12   12      4  2020      0       0
# ..           ...       ...         ...  ...    ...   ...    ...     ...
# 201    Venezuela   America  2020-04-12   12      4  2020      0       0
# 202      Vietnam      Asia  2020-04-12   12      4  2020      4       0
# 203        Yemen      Asia  2020-04-12   12      4  2020      0       0
# 204       Zambia    Africa  2020-04-12   12      4  2020      0       0
# 205     Zimbabwe    Africa  2020-04-12   12      4  2020      3       0
#
#     country_code  population
# 0            AFG  37172386.0
# 1            ALB   2866376.0
# ...

# %%
import pandas as pd
cal_df = pd.read_csv('Calories.csv')
new_cal_df = cal_df.dropna()
print(new_cal_df)
print(new_cal_df.info())
# Out:
#      Duration        Date  Pulse  Maxpulse  Calories
# 0          60   12/1/2020    110       130     409.1
# 1          60   12/2/2020    117       145     479.0
# 2          60   12/3/2020    103       135     340.0
# 3          45   12/5/2020    109       175     282.4
# 4          45   12/5/2020    109       175     282.4
# ..        ...         ...    ...       ...       ...
# 122        60  12/17/2020    119       169     336.7
# 123        60  12/14/2020    107       127     344.9
# 124        60  12/15/2020    111       151     368.5
# 125        60  12/16/2020     98       122     271.0
# 126        60  12/17/2020     97       124     275.3
#
# [123 rows x 5 columns]
# <class 'pandas.core.frame.DataFrame'>
# Index: 123 entries, 0 to 126
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  123 non-null    int64
#  1   Date      123 non-null    object
#  2   Pulse     123 non-null    int64
# ...

# %%
import pandas as pd
cal_df = pd.read_csv('Calories.csv')
cal_df.fillna(30,inplace=True)
print(cal_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Date      169 non-null    object
#  2   Pulse     169 non-null    int64
#  3   Maxpulse  169 non-null    int64
#  4   Calories  169 non-null    float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 6.7+ KB
# None

# %%
cal_df.fillna({"Calories": 130}, inplace=True)
print(cal_df.to_string())
# Out:
#      Duration        Date  Pulse  Maxpulse  Calories
# 0          60   12/1/2020    110       130     409.1
# 1          60   12/2/2020    117       145     479.0
# 2          60   12/3/2020    103       135     340.0
# 3          45   12/5/2020    109       175     282.4
# 4          45   12/5/2020    109       175     282.4
# 5          60   12/6/2020    102       127     300.0
# 6          60   12/7/2020    110       136     374.0
# 7          45   12/8/2020    104       134     253.3
# 8          30   12/9/2020    109       133     195.1
# 9          60  12/10/2020     98       124     269.0
# 10         60  12/11/2020    103       147     329.3
# 11         60  12/12/2020    100       120     250.7
# 12         60  12/12/2020    100       120     250.7
# 13         60  12/13/2020    104       132     379.3
# 14         60  12/14/2020     98       123     275.0
# 15         60  12/15/2020     98       120     215.2
# 16         60  12/16/2020    100       120     300.0
# ...

# %%
import pandas as pd
cal_df.loc[69,'Duration'] = 100
for x in cal_df.index:
    if cal_df.loc[x,'Duration']>120:
        cal_df.loc[x,'Duration'] = 120
print(cal_df)
# Out:
#      Duration        Date  Pulse  Maxpulse  Calories
# 0          60   12/1/2020    110       130     409.1
# 1          60   12/2/2020    117       145     479.0
# 2          60   12/3/2020    103       135     340.0
# 3          45   12/5/2020    109       175     282.4
# 4          45   12/5/2020    109       175     282.4
# 5          60   12/6/2020    102       127     300.0
# 6          60   12/7/2020    110       136     374.0
# 7          45   12/8/2020    104       134     253.3
# 8          30   12/9/2020    109       133     195.1
# 9          60  12/10/2020     98       124     269.0
# 10         60  12/11/2020    103       147     329.3
# 11         60  12/12/2020    100       120     250.7
# 12         60  12/12/2020    100       120     250.7
# 13         60  12/13/2020    104       132     379.3
# 14         60  12/14/2020     98       123     275.0
# 15         60  12/15/2020     98       120     215.2
# 16         60  12/16/2020    100       120     300.0
# ...

# %%
print(cal_df.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12      True
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# ...

# %%
import pandas as pd 
cal_df = pd.read_csv('Calories.csv')
cal_df.drop_duplicates(inplace = True)
print(cal_df.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# 66     False
# 67     False
# ...

# %%
import pandas as pd

cal_df = pd.read_csv('Calories.csv')

duplicate_row = cal_df.duplicated

duplicate_indices = cal_df[duplicate_row].index

print("Indices of duplicate rows: ")
print(duplicate_indices)
# Out:
# Indices of duplicate rows:
# Index([4, 12], dtype='int64')

# %%
#Calculate Mean,Median,Mode,STD 
import pandas as pd 
import matplotlib.pyplot as plt

coviddata = pd.read_csv('subset-covid-data.csv')
cases = coviddata.get('cases')
deaths  = coviddata.get('deaths')
print('Cases: Mean=',cases.mean(),'Median=',cases.median(),'STD=',cases.std())
print('Deaths: Mean=',deaths.mean(),'Median=',deaths.median(),'STD=',deaths.std())

max_case_index = cases.idxmax()
print('Country with max cases is ', coviddata.loc[max_case_index,'country'])
plt.figure(figsize=(15,8))
plt.hist(cases,bins=100)
plt.show()
# Out:
# Cases: Mean= 395.247572815534 Median= 11.5 STD= 2160.1764385637084
# Deaths: Mean= 29.71359223300971 Median= 0.0 STD= 159.53313138490057
# Country with max cases is  United_States_of_America

# %%
#Calculate Mean,Median,Mode,STD 
import pandas as pd 
data = pd.read_csv('Calories.csv')
Calories = data['Calories']
print('cal: Mean=',Calories.mean(),'Median=',Calories.median(),'Mode',Calories.mode()[0],'STD=',Calories.std())
# Out:
# cal: Mean= 374.459756097561 Median= 313.95 Mode 300.0 STD= 266.6358620110386

# %%
min_duration_row = data.loc[data['Duration'].idxmin()]
print("\nRow with minimum Duration:")
print(min_duration_row)
# Out:
# Row with minimum Duration:
# Duration            15
# Date        12/14/2020
# Pulse               80
# Maxpulse           100
# Calories          50.5
# Name: 93, dtype: object

# %%
#Relace empty row of calories with mean
data['Calories'].fillna(Calories.mean(),inplace=True)
print(data['Calories'])
# Out:
# 0       409.100000
# 1       479.000000
# 2       340.000000
# 3       282.400000
# 4       282.400000
# 5       300.000000
# 6       374.000000
# 7       253.300000
# 8       195.100000
# 9       269.000000
# 10      329.300000
# 11      250.700000
# 12      250.700000
# 13      379.300000
# 14      275.000000
# 15      215.200000
# 16      300.000000
# 17      374.459756
# 18      323.000000
# 19      243.000000
# 20      364.200000
# 21      282.000000
# 22      300.000000
# 23      246.000000
# 24      334.500000
# 25      250.000000
# 26      241.000000
# 27      374.459756
# 28      280.000000
# 29      380.300000
# 30      243.000000
# 31      180.100000
# 32      299.000000
# 33      223.000000
# 34      361.000000
# 35      415.000000
# 36      300.000000
# 37      300.000000
# 38      300.000000
# 39      266.000000
# 40      180.100000
# 41      286.000000
# 42      329.400000
# 43      400.000000
# 44      397.000000
# 45      273.000000
# 46      387.600000
# ...

# %%
#Calculate Mean,Median,Mode,STD 
import pandas as pd 
data = pd.read_csv('Calories.csv')
Calories = data['Calories']
print('cal: Mean=',Calories.mean(),'Median=',Calories.median(),'Mode',Calories.mode()[0],'STD=',Calories.std())
#Find roe with mini duration
min_duration_row = data.loc[data['Duration'].idxmin()]
print("\nRow with minimum Duration:")
print(min_duration_row)
#Relace empty row of calories with mean
data['Calories'].fillna(Calories.mean(),inplace=True)
print(data['Calories'])
# Out:
# cal: Mean= 374.459756097561 Median= 313.95 Mode 300.0 STD= 266.6358620110386
#
# Row with minimum Duration:
# Duration            15
# Date        12/14/2020
# Pulse               80
# Maxpulse           100
# Calories          50.5
# Name: 93, dtype: object
# 0       409.100000
# 1       479.000000
# 2       340.000000
# 3       282.400000
# 4       282.400000
# 5       300.000000
# 6       374.000000
# 7       253.300000
# 8       195.100000
# 9       269.000000
# 10      329.300000
# 11      250.700000
# 12      250.700000
# 13      379.300000
# 14      275.000000
# 15      215.200000
# 16      300.000000
# 17      374.459756
# 18      323.000000
# 19      243.000000
# 20      364.200000
# 21      282.000000
# 22      300.000000
# 23      246.000000
# 24      334.500000
# 25      250.000000
# 26      241.000000
# 27      374.459756
# 28      280.000000
# 29      380.300000
# 30      243.000000
# 31      180.100000
# 32      299.000000
# 33      223.000000
# 34      361.000000
# ...

# %%
# mydataset = {
#     'cars': ['BMW','Volvo','Ford'],
#     'passings' : [3,7,2],
#     'Model' : ['BMW1','Volvo3','Ford4']
# }
# myvar = pd.DataFrame(mydataset)
# print(myvar)
# Out:
#     cars  passings   Model
# 0    BMW         3    BMW1
# 1  Volvo         7  Volvo3
# 2   Ford         2   Ford4

# %%
# import pandas as pd

# a = [1, 7, 2]

# myvar = pd.Series(a)

# print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
# print(myvar[0])
# Out:
# 1

# %%
# import pandas as pd
# tdataset = {
#     'Airline':['Alaska','America West','American','Continental','Delta',"Northwest",'Southwest','TWA','United','US Airways'],
#     'Num_of_violation':[258,257,1745,973,1280,1097,535,642,1110,891],
#     'Average Fine per Violation ($)' : [5038.760, 3112.840, 2693.410, 5755.396, 3828.125, 2643.573, 3925.234, 2803.738, 2612.613, 3479.237]
# }
# dtdt = pd.DataFrame(tdataset)
# print(dtdt)
# Out:
#         Airline  Num_of_violation  Average Fine per Violation ($)
# 0        Alaska               258                        5038.760
# 1  America West               257                        3112.840
# 2      American              1745                        2693.410
# 3   Continental               973                        5755.396
# 4         Delta              1280                        3828.125
# 5     Northwest              1097                        2643.573
# 6     Southwest               535                        3925.234
# 7           TWA               642                        2803.738
# 8        United              1110                        2612.613
# 9    US Airways               891                        3479.237

# %%
# import pandas as pd
# dtdt = pd.Series(tdataset)
# print(dtdt)
# Out:
# Airline                           [Alaska, America West, American, Continental, ...
# Num_of_violation                  [258, 257, 1745, 973, 1280, 1097, 535, 642, 11...
# Average Fine per Violation ($)    [5038.76, 3112.84, 2693.41, 5755.396, 3828.125...
# dtype: object

# %%
# calories = {"day1": 420, "day2": 380, "day3": 390}

# myvar = pd.Series(calories)

# print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64
